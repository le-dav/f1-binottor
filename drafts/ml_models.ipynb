# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, accuracy_score, precision_score, make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, RobustScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping

from imblearn.combine import SMOTETomek
from scipy import stats

# %%
laps = pd.read_csv("../raw_data/new_clean_data.csv")
# Out:
# /var/folders/6b/wyfstlmd3c54c_2bb3_wfjh40000gn/T/ipykernel_33618/1252828457.py:1: DtypeWarning: Columns (29,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   laps = pd.read_csv("../raw_data/new_clean_data.csv")

# %%
laps.drop(columns= ["Unnamed: 0.1",
                   "Time",
                   "DriverNumber",
                   "LapTime",
                   "Stint", 
                   "PitOutTime", 
                   "PitInTime", 
                   "Sector1Time",
                   "Sector2Time", 
                   "Sector3Time", 
                   "Sector1SessionTime",
                   "Sector2SessionTime", 
                   "Sector3SessionTime", 
                   "SpeedI1", 
                   "SpeedI2",
                   "SpeedFL",
                   "SpeedST",
                   "LapStartTime",
                   "LapStartDate",
                   "TrackStatus",
                   "Deleted", 
                   "DeletedReason", 
                   "FastF1Generated", 
                   "IsAccurate",
                   "status_list",
                   "TotalLaps",
                   "Time_min", 
                   "Unnamed: 0", 
                   "Time_w", 
                   "AirTemp", 
                   "Humidity", 
                   "Pressure", 
                   "Rainfall",
                   "WindDirection",
                   "WindSpeed", 
                   "Final_Position", 
                   "LocationYear",
                   "next_compound",
                   "FreshTyre",
                   "pitting_this_lap"], inplace = True)

# %%
laps["pitting_next_lap"] = laps["pitting_next_lap"].apply(lambda x: 1 if x == True else 0)

# %%
laps_for_model = laps.copy()
train_df = laps_for_model[laps_for_model["Year"] < 2022]
val_df = laps_for_model[laps_for_model["Year"] == 2022]
test_df = laps_for_model[laps_for_model["Year"] == 2023]
train_df_shuffled = train_df.sample(frac=1)
val_df_shuffled = val_df.sample(frac=1)
test_df_shuffled = test_df.sample(frac=1)

y_train = train_df_shuffled["pitting_next_lap"]
y_val = val_df_shuffled["pitting_next_lap"]
y_test = test_df_shuffled["pitting_next_lap"]

X_train = train_df_shuffled.drop(columns="pitting_next_lap")
X_val = val_df_shuffled.drop(columns="pitting_next_lap")
X_test = test_df_shuffled.drop(columns="pitting_next_lap")

cat_features = ["Driver", "Compound", "Team", "Location", "second_compound", "TyreStressLevel", "status", "close_ahead", "close_behind", "is_pitting_ahead", "is_pitting_behind", "IsPersonalBest", "Position", "Year"]
cat_features_preproc = make_pipeline(OneHotEncoder(sparse=False, handle_unknown="ignore"))
num_features = ["LapNumber", "TyreLife", "LastTeamRanking", "TrackTemp"]
num_features_preproc = make_pipeline(RobustScaler())

preproc_baseline = make_column_transformer((cat_features_preproc, cat_features),
                                           (num_features_preproc, num_features),
                                           remainder="passthrough")

preproc_baseline.fit(X_train)
X_train_preproc = preproc_baseline.transform(X_train)
X_test_preproc = preproc_baseline.transform(X_test)
X_val_preproc = preproc_baseline.transform(X_val)

smt = SMOTETomek(sampling_strategy=0.5)
X_train_preproc_resamp, y_train_resamp = smt.fit_resample(X_train_preproc, y_train)

def custom_metric(y_test, y_pred_rf):
    predictions = list(y_pred_rf)
    reality = y_test.to_list()
    tracker = 0
    ones_count = reality.count(1)

    for i in range(len(reality)):
        if reality[i] == 1:
            if predictions[i] == 1:
                tracker += 1
            elif i > 0 and predictions[i - 1] == 1:
                tracker += 1
            elif i < len(predictions) - 1 and predictions[i + 1] == 1:
                tracker += 1

    return tracker / ones_count
# Out:
# /Users/rosemansion/.pyenv/versions/3.10.6/envs/f1-binottor/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # KNN 11  neighbors

# %%
model_knn = KNeighborsClassifier(n_neighbors=11)

# %%
model_knn.fit(X_train_preproc_resamp,y_train_resamp)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred_knn = model_knn.predict(X_test_preproc)

# %%
custom_metric(y_test,y_pred_knn)
# Out:
# 0.6971830985915493

# %%
X_test_eval_df = X_test.copy()
y_test_eval_df = y_test.copy()
X_test_eval_df["RealPitting"] = y_test_eval_df
X_test_eval_df["ModelPitting"] = y_pred_knn
X_test_eval_df.sort_values(by = ["Driver", "Location", "LapNumber"], inplace=True)

# %%
X_test_eval_df[(X_test_eval_df["Driver"] == "VER") & (X_test_eval_df["Location"] == "Baku")]
# Out:
#       Driver  LapNumber  IsPersonalBest Compound  TyreLife     Team  Position  \
# 64421    VER        6.0           False   MEDIUM       6.0  RedBull       1.0
# 64422    VER        7.0            True   MEDIUM       7.0  RedBull       1.0
# 64423    VER        8.0            True   MEDIUM       8.0  RedBull       1.0
# 64424    VER        9.0           False   MEDIUM       9.0  RedBull       1.0
# 64425    VER       10.0           False   MEDIUM      10.0  RedBull       3.0
# 64426    VER       11.0           False     HARD       1.0  RedBull       7.0
# 64427    VER       12.0           False     HARD       2.0  RedBull       3.0
# 64428    VER       13.0           False     HARD       3.0  RedBull       3.0
# 64429    VER       14.0           False     HARD       4.0  RedBull       2.0
# 64430    VER       15.0            True     HARD       5.0  RedBull       2.0
# 64431    VER       16.0            True     HARD       6.0  RedBull       2.0
# 64432    VER       17.0           False     HARD       7.0  RedBull       2.0
# 64433    VER       18.0            True     HARD       8.0  RedBull       2.0
# 64434    VER       19.0           False     HARD       9.0  RedBull       2.0
# 64435    VER       20.0           False     HARD      10.0  RedBull       2.0
# 64436    VER       21.0           False     HARD      11.0  RedBull       2.0
# 64437    VER       22.0           False     HARD      12.0  RedBull       2.0
# 64438    VER       23.0           False     HARD      13.0  RedBull       2.0
# 64439    VER       24.0           False     HARD      14.0  RedBull       2.0
# 64440    VER       25.0           False     HARD      15.0  RedBull       2.0
# 64441    VER       26.0           False     HARD      16.0  RedBull       2.0
# 64442    VER       27.0           False     HARD      17.0  RedBull       2.0
# 64443    VER       28.0           False     HARD      18.0  RedBull       2.0
# 64444    VER       29.0           False     HARD      19.0  RedBull       2.0
# 64445    VER       30.0           False     HARD      20.0  RedBull       2.0
# 64446    VER       31.0            True     HARD      21.0  RedBull       2.0
# 64447    VER       32.0           False     HARD      22.0  RedBull       2.0
# 64448    VER       33.0            True     HARD      23.0  RedBull       2.0
# 64449    VER       34.0            True     HARD      24.0  RedBull       2.0
# 64450    VER       35.0            True     HARD      25.0  RedBull       2.0
# 64451    VER       36.0            True     HARD      26.0  RedBull       2.0
# 64452    VER       37.0           False     HARD      27.0  RedBull       2.0
# 64453    VER       38.0           False     HARD      28.0  RedBull       2.0
# 64454    VER       39.0           False     HARD      29.0  RedBull       2.0
# 64455    VER       40.0           False     HARD      30.0  RedBull       2.0
# 64456    VER       41.0           False     HARD      31.0  RedBull       2.0
# 64457    VER       42.0           False     HARD      32.0  RedBull       2.0
# 64458    VER       43.0            True     HARD      33.0  RedBull       2.0
# 64459    VER       44.0           False     HARD      34.0  RedBull       2.0
# 64460    VER       45.0           False     HARD      35.0  RedBull       2.0
# 64461    VER       46.0            True     HARD      36.0  RedBull       2.0
# 64462    VER       47.0           False     HARD      37.0  RedBull       2.0
# 64463    VER       48.0            True     HARD      38.0  RedBull       2.0
# 64464    VER       49.0            True     HARD      39.0  RedBull       2.0
# 64465    VER       50.0           False     HARD      40.0  RedBull       2.0
# 64466    VER       51.0            True     HARD      41.0  RedBull       2.0
#
#       Location  Year  LastTeamRanking  ...  status  RaceProgress  \
# 64421     Baku  2023              1.0  ...       1      0.117647
# 64422     Baku  2023              1.0  ...       1      0.137255
# 64423     Baku  2023              1.0  ...       1      0.156863
# 64424     Baku  2023              1.0  ...       1      0.176471
# 64425     Baku  2023              1.0  ...       1      0.196078
# 64426     Baku  2023              1.0  ...       2      0.215686
# 64427     Baku  2023              1.0  ...       3      0.235294
# 64428     Baku  2023              1.0  ...       4      0.254902
# 64429     Baku  2023              1.0  ...       1      0.274510
# 64430     Baku  2023              1.0  ...       1      0.294118
# 64431     Baku  2023              1.0  ...       1      0.313725
# 64432     Baku  2023              1.0  ...       1      0.333333
# 64433     Baku  2023              1.0  ...       1      0.352941
# 64434     Baku  2023              1.0  ...       1      0.372549
# 64435     Baku  2023              1.0  ...       1      0.392157
# 64436     Baku  2023              1.0  ...       1      0.411765
# 64437     Baku  2023              1.0  ...       1      0.431373
# 64438     Baku  2023              1.0  ...       1      0.450980
# 64439     Baku  2023              1.0  ...       1      0.470588
# 64440     Baku  2023              1.0  ...       1      0.490196
# 64441     Baku  2023              1.0  ...       1      0.509804
# 64442     Baku  2023              1.0  ...       1      0.529412
# 64443     Baku  2023              1.0  ...       1      0.549020
# 64444     Baku  2023              1.0  ...       1      0.568627
# 64445     Baku  2023              1.0  ...       1      0.588235
# 64446     Baku  2023              1.0  ...       1      0.607843
# 64447     Baku  2023              1.0  ...       1      0.627451
# 64448     Baku  2023              1.0  ...       1      0.647059
# 64449     Baku  2023              1.0  ...       1      0.666667
# 64450     Baku  2023              1.0  ...       1      0.686275
# 64451     Baku  2023              1.0  ...       1      0.705882
# 64452     Baku  2023              1.0  ...       1      0.725490
# 64453     Baku  2023              1.0  ...       1      0.745098
# 64454     Baku  2023              1.0  ...       1      0.764706
# 64455     Baku  2023              1.0  ...       1      0.784314
# 64456     Baku  2023              1.0  ...       1      0.803922
# 64457     Baku  2023              1.0  ...       1      0.823529
# 64458     Baku  2023              1.0  ...       1      0.843137
# 64459     Baku  2023              1.0  ...       1      0.862745
# 64460     Baku  2023              1.0  ...       1      0.882353
# 64461     Baku  2023              1.0  ...       1      0.901961
# 64462     Baku  2023              1.0  ...       1      0.921569
# 64463     Baku  2023              1.0  ...       1      0.941176
# 64464     Baku  2023              1.0  ...       1      0.960784
# 64465     Baku  2023              1.0  ...       1      0.980392
# 64466     Baku  2023              1.0  ...       1      1.000000
#
#        TyreStressLevel  TrackTemp  close_ahead  close_behind  \
# 64421                3       43.3        False         False
# 64422                3       41.6        False         False
# 64423                3       41.7        False         False
# 64424                3       42.2        False         False
# 64425                3       42.7        False          True
# 64426                3       41.0         True         False
# 64427                3       41.0        False         False
# 64428                3       41.7        False         False
# 64429                3       42.5        False         False
# 64430                3       43.0        False          True
# 64431                3       42.5        False          True
# 64432                3       42.6        False          True
# 64433                3       42.6        False          True
# 64434                3       41.9        False          True
# 64435                3       41.0        False          True
# 64436                3       40.8        False          True
# 64437                3       40.8        False          True
# 64438                3       40.6        False          True
# 64439                3       40.4        False          True
# 64440                3       40.9        False          True
# 64441                3       40.5        False          True
# 64442                3       40.5        False          True
# 64443                3       40.5         True          True
# 64444                3       41.0         True          True
# 64445                3       40.7         True          True
# 64446                3       40.9         True          True
# 64447                3       40.7         True          True
# 64448                3       40.1         True          True
# 64449                3       39.8         True          True
# 64450                3       39.4         True          True
# 64451                3       39.4         True          True
# 64452                3       39.1         True          True
# 64453                3       38.8         True          True
# 64454                3       38.8         True          True
# 64455                3       38.9         True          True
# 64456                3       37.6         True          True
# 64457                3       38.0         True          True
# 64458                3       37.7         True          True
# 64459                3       37.5         True          True
# 64460                3       37.1         True          True
# 64461                3       36.5         True          True
# 64462                3       36.5         True          True
# 64463                3       35.8         True          True
# 64464                3       35.6         True          True
# 64465                3       35.1         True          True
# 64466                3       35.1         True          True
#
#        is_pitting_ahead  is_pitting_behind  RealPitting  ModelPitting
# 64421             False              False            0             0
# 64422             False              False            0             1
# 64423             False              False            0             1
# 64424             False              False            1             0
# 64425             False              False            0             0
# 64426              True              False            0             0
# 64427             False              False            0             0
# 64428             False              False            0             0
# 64429             False              False            0             0
# 64430             False              False            0             0
# 64431             False              False            0             0
# 64432             False              False            0             0
# 64433             False              False            0             0
# 64434             False              False            0             0
# 64435             False              False            0             0
# 64436             False              False            0             0
# 64437             False              False            0             0
# 64438             False              False            0             0
# 64439             False              False            0             0
# 64440             False              False            0             0
# 64441             False              False            0             0
# 64442             False              False            0             0
# 64443             False              False            0             0
# 64444             False              False            0             0
# 64445             False              False            0             0
# 64446             False              False            0             0
# 64447             False              False            0             0
# 64448             False              False            0             0
# 64449             False              False            0             0
# 64450             False              False            0             0
# 64451             False              False            0             0
# 64452             False              False            0             0
# 64453             False              False            0             0
# 64454             False              False            0             0
# 64455             False              False            0             0
# 64456             False              False            0             0
# 64457             False              False            0             0
# 64458             False              False            0             0
# 64459             False              False            0             0
# 64460             False              False            0             0
# 64461             False              False            0             0
# 64462             False              False            0             0
# 64463             False              False            0             0
# 64464             False              False            0             0
# 64465             False              False            0             0
# 64466             False              False            0             0
#
# [46 rows x 21 columns]

# %% [markdown]
# LECLERC
# Barcelona: 4/5
# Baku: 4/5
# Jeddah: 2,5/5
#
# SAINZ
# Barcelona: 2/5
# Baku: 2/5
# Jeddah: 3/5
#
# HAMILTON
# Barcelona: 2/5
# Baku: 1/5
# Jeddah: 3/5
#
# VERSTAPPEN
# Barcelona: 3/5
# Baku: 4/5
# Jeddah: 2/5

# %% [markdown]
# # SVM

# %%
model_svm = SVC()
model_svm.fit(X_train_preproc_resamp,y_train_resamp)
y_pred_svm = model_svm.predict(X_test_preproc)
custom_metric(y_test,y_pred_svm)
# Out:
# 0.823943661971831

# %%
X_test_eval_df = X_test.copy()
y_test_eval_df = y_test.copy()
X_test_eval_df["RealPitting"] = y_test_eval_df
X_test_eval_df["ModelPitting"] = y_pred_svm
X_test_eval_df.sort_values(by = ["Driver", "Location", "LapNumber"], inplace=True)

X_test_eval_df[(X_test_eval_df["Driver"] == "VER") & (X_test_eval_df["Location"] == "Barcelona")]
# Out:
#       Driver  LapNumber  IsPersonalBest Compound  TyreLife     Team  Position  \
# 65695    VER        7.0           False   MEDIUM       7.0  RedBull       1.0
# 65696    VER        8.0            True   MEDIUM       8.0  RedBull       1.0
# 65697    VER        9.0           False   MEDIUM       9.0  RedBull       1.0
# 65698    VER       10.0           False   MEDIUM      10.0  RedBull       1.0
# 65699    VER       11.0           False   MEDIUM      11.0  RedBull       1.0
# 65700    VER       12.0           False   MEDIUM      12.0  RedBull       1.0
# 65701    VER       13.0           False   MEDIUM      13.0  RedBull       1.0
# 65702    VER       14.0           False   MEDIUM      14.0  RedBull       1.0
# 65703    VER       15.0           False   MEDIUM      15.0  RedBull       1.0
# 65704    VER       16.0           False   MEDIUM      16.0  RedBull       1.0
# 65705    VER       17.0           False   MEDIUM      17.0  RedBull       1.0
# 65706    VER       18.0           False   MEDIUM      18.0  RedBull       1.0
# 65707    VER       19.0           False   MEDIUM      19.0  RedBull       1.0
# 65708    VER       20.0           False   MEDIUM      20.0  RedBull       1.0
# 65709    VER       21.0           False   MEDIUM      21.0  RedBull       1.0
# 65710    VER       22.0            True   MEDIUM      22.0  RedBull       1.0
# 65711    VER       23.0           False   MEDIUM      23.0  RedBull       1.0
# 65712    VER       24.0           False   MEDIUM      24.0  RedBull       1.0
# 65713    VER       25.0           False   MEDIUM      25.0  RedBull       1.0
# 65714    VER       26.0           False   MEDIUM      26.0  RedBull       1.0
# 65715    VER       27.0           False     HARD       1.0  RedBull       1.0
# 65716    VER       28.0            True     HARD       2.0  RedBull       1.0
# 65717    VER       29.0           False     HARD       3.0  RedBull       1.0
# 65718    VER       30.0           False     HARD       4.0  RedBull       1.0
# 65719    VER       31.0           False     HARD       5.0  RedBull       1.0
# 65720    VER       32.0           False     HARD       6.0  RedBull       1.0
# 65721    VER       33.0           False     HARD       7.0  RedBull       1.0
# 65722    VER       34.0           False     HARD       8.0  RedBull       1.0
# 65723    VER       35.0           False     HARD       9.0  RedBull       1.0
# 65724    VER       36.0           False     HARD      10.0  RedBull       1.0
# 65725    VER       37.0           False     HARD      11.0  RedBull       1.0
# 65726    VER       38.0           False     HARD      12.0  RedBull       1.0
# 65727    VER       39.0           False     HARD      13.0  RedBull       1.0
# 65728    VER       40.0           False     HARD      14.0  RedBull       1.0
# 65729    VER       41.0           False     HARD      15.0  RedBull       1.0
# 65730    VER       42.0           False     HARD      16.0  RedBull       1.0
# 65731    VER       43.0           False     HARD      17.0  RedBull       1.0
# 65732    VER       44.0           False     HARD      18.0  RedBull       1.0
# 65733    VER       45.0           False     HARD      19.0  RedBull       1.0
# 65734    VER       46.0           False     HARD      20.0  RedBull       1.0
# 65735    VER       47.0           False     HARD      21.0  RedBull       1.0
# 65736    VER       48.0           False     HARD      22.0  RedBull       1.0
# 65737    VER       49.0           False     HARD      23.0  RedBull       1.0
# 65738    VER       50.0           False     HARD      24.0  RedBull       1.0
# 65739    VER       51.0           False     HARD      25.0  RedBull       1.0
# 65740    VER       52.0           False     HARD      26.0  RedBull       1.0
# 65741    VER       53.0           False     SOFT       3.0  RedBull       1.0
# 65742    VER       54.0            True     SOFT       4.0  RedBull       1.0
# 65743    VER       55.0           False     SOFT       5.0  RedBull       1.0
# 65744    VER       56.0           False     SOFT       6.0  RedBull       1.0
# 65745    VER       57.0            True     SOFT       7.0  RedBull       1.0
# 65746    VER       58.0           False     SOFT       8.0  RedBull       1.0
# 65747    VER       59.0           False     SOFT       9.0  RedBull       1.0
# 65748    VER       60.0           False     SOFT      10.0  RedBull       1.0
# 65749    VER       61.0            True     SOFT      11.0  RedBull       1.0
# 65750    VER       62.0           False     SOFT      12.0  RedBull       1.0
# 65751    VER       63.0           False     SOFT      13.0  RedBull       1.0
# 65752    VER       64.0           False     SOFT      14.0  RedBull       1.0
# 65753    VER       65.0           False     SOFT      15.0  RedBull       1.0
# 65754    VER       66.0           False     SOFT      16.0  RedBull       1.0
#
#         Location  Year  LastTeamRanking  ...  status  RaceProgress  \
# 65695  Barcelona  2023              1.0  ...       1      0.106061
# 65696  Barcelona  2023              1.0  ...       1      0.121212
# 65697  Barcelona  2023              1.0  ...       1      0.136364
# 65698  Barcelona  2023              1.0  ...       1      0.151515
# 65699  Barcelona  2023              1.0  ...       1      0.166667
# 65700  Barcelona  2023              1.0  ...       1      0.181818
# 65701  Barcelona  2023              1.0  ...       1      0.196970
# 65702  Barcelona  2023              1.0  ...       1      0.212121
# 65703  Barcelona  2023              1.0  ...       1      0.227273
# 65704  Barcelona  2023              1.0  ...       1      0.242424
# 65705  Barcelona  2023              1.0  ...       1      0.257576
# 65706  Barcelona  2023              1.0  ...       1      0.272727
# 65707  Barcelona  2023              1.0  ...       1      0.287879
# 65708  Barcelona  2023              1.0  ...       1      0.303030
# 65709  Barcelona  2023              1.0  ...       1      0.318182
# 65710  Barcelona  2023              1.0  ...       1      0.333333
# 65711  Barcelona  2023              1.0  ...       1      0.348485
# 65712  Barcelona  2023              1.0  ...       1      0.363636
# 65713  Barcelona  2023              1.0  ...       1      0.378788
# 65714  Barcelona  2023              1.0  ...       1      0.393939
# 65715  Barcelona  2023              1.0  ...       1      0.409091
# 65716  Barcelona  2023              1.0  ...       1      0.424242
# 65717  Barcelona  2023              1.0  ...       1      0.439394
# 65718  Barcelona  2023              1.0  ...       1      0.454545
# 65719  Barcelona  2023              1.0  ...       1      0.469697
# 65720  Barcelona  2023              1.0  ...       1      0.484848
# 65721  Barcelona  2023              1.0  ...       1      0.500000
# 65722  Barcelona  2023              1.0  ...       1      0.515152
# 65723  Barcelona  2023              1.0  ...       1      0.530303
# 65724  Barcelona  2023              1.0  ...       1      0.545455
# 65725  Barcelona  2023              1.0  ...       1      0.560606
# 65726  Barcelona  2023              1.0  ...       1      0.575758
# 65727  Barcelona  2023              1.0  ...       1      0.590909
# 65728  Barcelona  2023              1.0  ...       1      0.606061
# 65729  Barcelona  2023              1.0  ...       1      0.621212
# 65730  Barcelona  2023              1.0  ...       1      0.636364
# 65731  Barcelona  2023              1.0  ...       1      0.651515
# 65732  Barcelona  2023              1.0  ...       1      0.666667
# 65733  Barcelona  2023              1.0  ...       1      0.681818
# 65734  Barcelona  2023              1.0  ...       1      0.696970
# 65735  Barcelona  2023              1.0  ...       1      0.712121
# 65736  Barcelona  2023              1.0  ...       1      0.727273
# 65737  Barcelona  2023              1.0  ...       1      0.742424
# 65738  Barcelona  2023              1.0  ...       1      0.757576
# 65739  Barcelona  2023              1.0  ...       1      0.772727
# 65740  Barcelona  2023              1.0  ...       1      0.787879
# 65741  Barcelona  2023              1.0  ...       1      0.803030
# 65742  Barcelona  2023              1.0  ...       1      0.818182
# 65743  Barcelona  2023              1.0  ...       1      0.833333
# 65744  Barcelona  2023              1.0  ...       1      0.848485
# 65745  Barcelona  2023              1.0  ...       1      0.863636
# 65746  Barcelona  2023              1.0  ...       1      0.878788
# 65747  Barcelona  2023              1.0  ...       1      0.893939
# 65748  Barcelona  2023              1.0  ...       1      0.909091
# 65749  Barcelona  2023              1.0  ...       1      0.924242
# 65750  Barcelona  2023              1.0  ...       1      0.939394
# 65751  Barcelona  2023              1.0  ...       1      0.954545
# 65752  Barcelona  2023              1.0  ...       1      0.969697
# 65753  Barcelona  2023              1.0  ...       1      0.984848
# 65754  Barcelona  2023              1.0  ...       1      1.000000
#
#        TyreStressLevel  TrackTemp  close_ahead  close_behind  \
# 65695                1       32.2        False          True
# 65696                1       31.6        False          True
# 65697                1       31.8        False          True
# 65698                1       31.9        False          True
# 65699                1       31.5        False          True
# 65700                1       31.5        False          True
# 65701                1       31.7        False          True
# 65702                1       31.9        False          True
# 65703                1       31.2        False          True
# 65704                1       31.2        False          True
# 65705                1       31.0        False          True
# 65706                1       30.9        False          True
# 65707                1       31.2        False          True
# 65708                1       31.4        False          True
# 65709                1       31.2        False          True
# 65710                1       31.1        False          True
# 65711                1       30.9        False          True
# 65712                1       30.9        False          True
# 65713                1       31.0        False          True
# 65714                1       30.3        False          True
# 65715                1       30.4        False          True
# 65716                1       30.5        False          True
# 65717                1       30.5        False          True
# 65718                1       30.1        False          True
# 65719                1       30.5        False          True
# 65720                1       30.5        False          True
# 65721                1       30.6        False          True
# 65722                1       30.2        False          True
# 65723                1       30.3        False          True
# 65724                1       30.4        False          True
# 65725                1       30.4        False          True
# 65726                1       30.1        False          True
# 65727                1       29.9        False          True
# 65728                1       29.9        False          True
# 65729                1       29.9        False          True
# 65730                1       29.9        False          True
# 65731                1       29.9        False          True
# 65732                1       29.8        False          True
# 65733                1       29.6        False          True
# 65734                1       29.8        False          True
# 65735                1       29.1        False          True
# 65736                1       29.3        False          True
# 65737                1       29.7        False          True
# 65738                1       29.5        False          True
# 65739                1       28.7        False          True
# 65740                1       28.7        False          True
# 65741                1       28.4        False          True
# 65742                1       28.3        False          True
# 65743                1       28.4        False          True
# 65744                1       28.2        False          True
# 65745                1       28.1        False          True
# 65746                1       28.2        False          True
# 65747                1       28.2        False          True
# 65748                1       27.9        False          True
# 65749                1       27.7        False          True
# 65750                1       27.3        False          True
# 65751                1       27.2        False          True
# 65752                1       26.8        False          True
# 65753                1       27.1        False          True
# 65754                1       27.5        False          True
#
#        is_pitting_ahead  is_pitting_behind  RealPitting  ModelPitting
# 65695             False              False            0             0
# 65696             False              False            0             0
# 65697             False              False            0             0
# 65698             False              False            0             0
# 65699             False              False            0             0
# 65700             False              False            0             0
# 65701             False              False            0             0
# 65702             False              False            0             0
# 65703             False              False            0             0
# 65704             False              False            0             0
# 65705             False              False            0             0
# 65706             False              False            0             0
# 65707             False              False            0             0
# 65708             False              False            0             0
# 65709             False              False            0             0
# 65710             False              False            0             0
# 65711             False              False            0             0
# 65712             False               True            0             1
# 65713             False               True            1             1
# 65714             False              False            0             1
# 65715             False              False            0             0
# 65716             False              False            0             0
# 65717             False              False            0             0
# 65718             False              False            0             0
# 65719             False              False            0             0
# 65720             False              False            0             0
# 65721             False              False            0             0
# 65722             False              False            0             0
# 65723             False              False            0             0
# 65724             False              False            0             0
# 65725             False              False            0             0
# 65726             False              False            0             0
# 65727             False              False            0             0
# 65728             False              False            0             0
# 65729             False              False            0             0
# 65730             False              False            0             0
# 65731             False              False            0             0
# 65732             False              False            0             0
# 65733             False              False            0             0
# 65734             False              False            0             0
# 65735             False              False            0             0
# 65736             False              False            0             0
# 65737             False              False            0             0
# 65738             False               True            0             0
# 65739             False              False            1             0
# 65740             False              False            0             0
# 65741             False              False            0             0
# 65742             False              False            0             0
# 65743             False              False            0             0
# 65744             False              False            0             0
# 65745             False              False            0             0
# 65746             False              False            0             0
# 65747             False              False            0             0
# 65748             False              False            0             0
# 65749             False              False            0             0
# 65750             False              False            0             0
# 65751             False              False            0             0
# 65752             False              False            0             0
# 65753             False              False            0             0
# 65754             False              False            0             0
#
# [60 rows x 21 columns]

# %% [markdown]
# LECLERC \
# Barcelona: 2/5 \
# Baku: 2,5/5  \
# Jeddah: 3/5 \
# moyenne: 2,5
#
# SAINZ \
# Barcelona: 3,5/5 \
# Baku: 0/5 \
# Jeddah: 3/5 \
# moyenne: 2,1
#
# HAMILTON  \
# Barcelona: 3/5 \
# Baku: 3/5 \
# Jeddah: 3,5/5 \
# moyenne: 3
#
# VERSTAPPEN \
# Barcelona: 4/5 \
# Baku: 0/5 \
# Jeddah: 0/5 \
# moyenne: 1,3
