# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score, accuracy_score, precision_score, make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, RobustScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

from tensorflow.keras.utils import to_categorical
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping

from imblearn.combine import SMOTETomek
from scipy import stats

# %%
laps = pd.read_csv("../raw_data/new_clean_data.csv")
# Out:
# /var/folders/6b/wyfstlmd3c54c_2bb3_wfjh40000gn/T/ipykernel_33618/1252828457.py:1: DtypeWarning: Columns (29,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   laps = pd.read_csv("../raw_data/new_clean_data.csv")

# %%
laps.drop(columns= ["Unnamed: 0.1",
                   "Time",
                   "DriverNumber",
                   "LapTime",
                   "Stint", 
                   "PitOutTime", 
                   "PitInTime", 
                   "Sector1Time",
                   "Sector2Time", 
                   "Sector3Time", 
                   "Sector1SessionTime",
                   "Sector2SessionTime", 
                   "Sector3SessionTime", 
                   "SpeedI1", 
                   "SpeedI2",
                   "SpeedFL",
                   "SpeedST",
                   "LapStartTime",
                   "LapStartDate",
                   "TrackStatus",
                   "Deleted", 
                   "DeletedReason", 
                   "FastF1Generated", 
                   "IsAccurate",
                   "status_list",
                   "TotalLaps",
                   "Time_min", 
                   "Unnamed: 0", 
                   "Time_w", 
                   "AirTemp", 
                   "Humidity", 
                   "Pressure", 
                   "Rainfall",
                   "WindDirection",
                   "WindSpeed", 
                   "Final_Position", 
                   "LocationYear",
                   "next_compound",
                   "FreshTyre",
                   "pitting_this_lap"], inplace = True)

# %%
laps["pitting_next_lap"] = laps["pitting_next_lap"].apply(lambda x: 1 if x == True else 0)

# %%
laps_for_model = laps.copy()
train_df = laps_for_model[laps_for_model["Year"] < 2022]
val_df = laps_for_model[laps_for_model["Year"] == 2022]
test_df = laps_for_model[laps_for_model["Year"] == 2023]
train_df_shuffled = train_df.sample(frac=1)
val_df_shuffled = val_df.sample(frac=1)
test_df_shuffled = test_df.sample(frac=1)

y_train = train_df_shuffled["pitting_next_lap"]
y_val = val_df_shuffled["pitting_next_lap"]
y_test = test_df_shuffled["pitting_next_lap"]

X_train = train_df_shuffled.drop(columns="pitting_next_lap")
X_val = val_df_shuffled.drop(columns="pitting_next_lap")
X_test = test_df_shuffled.drop(columns="pitting_next_lap")

cat_features = ["Driver", "Compound", "Team", "Location", "second_compound", "TyreStressLevel", "status", "close_ahead", "close_behind", "is_pitting_ahead", "is_pitting_behind", "IsPersonalBest", "Position", "Year"]
cat_features_preproc = make_pipeline(OneHotEncoder(sparse=False, handle_unknown="ignore"))
num_features = ["LapNumber", "TyreLife", "LastTeamRanking", "TrackTemp"]
num_features_preproc = make_pipeline(RobustScaler())

preproc_baseline = make_column_transformer((cat_features_preproc, cat_features),
                                           (num_features_preproc, num_features),
                                           remainder="passthrough")

preproc_baseline.fit(X_train)
X_train_preproc = preproc_baseline.transform(X_train)
X_test_preproc = preproc_baseline.transform(X_test)
X_val_preproc = preproc_baseline.transform(X_val)

smt = SMOTETomek(sampling_strategy=0.5)
X_train_preproc_resamp, y_train_resamp = smt.fit_resample(X_train_preproc, y_train)

def custom_metric(y_test, y_pred_rf):
    predictions = list(y_pred_rf)
    reality = y_test.to_list()
    tracker = 0
    ones_count = reality.count(1)

    for i in range(len(reality)):
        if reality[i] == 1:
            if predictions[i] == 1:
                tracker += 1
            elif i > 0 and predictions[i - 1] == 1:
                tracker += 1
            elif i < len(predictions) - 1 and predictions[i + 1] == 1:
                tracker += 1

    return tracker / ones_count
# Out:
# /Users/rosemansion/.pyenv/versions/3.10.6/envs/f1-binottor/lib/python3.10/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # KNN 11  neighbors

# %%
model_knn = KNeighborsClassifier(n_neighbors=11)

# %%
model_knn.fit(X_train_preproc_resamp,y_train_resamp)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
y_pred_knn = model_knn.predict(X_test_preproc)

# %%
custom_metric(y_test,y_pred_knn)
# Out:
# 0.6971830985915493

# %%
X_test_eval_df = X_test.copy()
y_test_eval_df = y_test.copy()
X_test_eval_df["RealPitting"] = y_test_eval_df
X_test_eval_df["ModelPitting"] = y_pred_rf
X_test_eval_df.sort_values(by = ["Driver", "Location", "LapNumber"], inplace=True)

# %%
X_test_eval_df[(X_test_eval_df["Driver"] == "SAI") & (X_test_eval_df["Location"] == "Sakhir")]
# Out:
#       Driver  LapNumber  IsPersonalBest Compound  TyreLife     Team  Position  \
# 62992    SAI        6.0           False     SOFT       9.0  Ferrari       4.0
# 62993    SAI        7.0           False     SOFT      10.0  Ferrari       4.0
# 62994    SAI        8.0           False     SOFT      11.0  Ferrari       4.0
# 62995    SAI        9.0           False     SOFT      12.0  Ferrari       4.0
# 62996    SAI       10.0           False     SOFT      13.0  Ferrari       4.0
# 62997    SAI       11.0           False     SOFT      14.0  Ferrari       4.0
# 62998    SAI       12.0           False     SOFT      15.0  Ferrari       4.0
# 62999    SAI       13.0           False     SOFT      16.0  Ferrari       4.0
# 63000    SAI       14.0           False     HARD       1.0  Ferrari       6.0
# 63001    SAI       15.0            True     HARD       2.0  Ferrari       5.0
# 63002    SAI       16.0           False     HARD       3.0  Ferrari       4.0
# 63003    SAI       17.0           False     HARD       4.0  Ferrari       4.0
# 63004    SAI       18.0           False     HARD       5.0  Ferrari       4.0
# 63005    SAI       19.0           False     HARD       6.0  Ferrari       4.0
# 63006    SAI       20.0           False     HARD       7.0  Ferrari       4.0
# 63007    SAI       21.0           False     HARD       8.0  Ferrari       4.0
# 63008    SAI       22.0           False     HARD       9.0  Ferrari       4.0
# 63009    SAI       23.0           False     HARD      10.0  Ferrari       4.0
# 63010    SAI       24.0           False     HARD      11.0  Ferrari       4.0
# 63011    SAI       25.0           False     HARD      12.0  Ferrari       4.0
# 63012    SAI       26.0           False     HARD      13.0  Ferrari       4.0
# 63013    SAI       27.0           False     HARD      14.0  Ferrari       4.0
# 63014    SAI       28.0           False     HARD      15.0  Ferrari       4.0
# 63015    SAI       29.0           False     HARD      16.0  Ferrari       4.0
# 63016    SAI       30.0           False     HARD      17.0  Ferrari       4.0
# 63017    SAI       31.0           False     HARD      18.0  Ferrari       4.0
# 63018    SAI       32.0           False     HARD       1.0  Ferrari       5.0
# 63019    SAI       33.0            True     HARD       2.0  Ferrari       5.0
# 63020    SAI       34.0            True     HARD       3.0  Ferrari       5.0
# 63021    SAI       35.0            True     HARD       4.0  Ferrari       4.0
# 63022    SAI       36.0           False     HARD       5.0  Ferrari       4.0
# 63023    SAI       37.0            True     HARD       6.0  Ferrari       4.0
# 63024    SAI       38.0           False     HARD       7.0  Ferrari       4.0
# 63025    SAI       39.0           False     HARD       8.0  Ferrari       4.0
# 63026    SAI       40.0           False     HARD       9.0  Ferrari       3.0
# 63027    SAI       41.0           False     HARD      10.0  Ferrari       3.0
# 63028    SAI       42.0           False     HARD      11.0  Ferrari       3.0
# 63029    SAI       43.0           False     HARD      12.0  Ferrari       3.0
# 63030    SAI       44.0           False     HARD      13.0  Ferrari       3.0
# 63031    SAI       45.0           False     HARD      14.0  Ferrari       4.0
# 63032    SAI       46.0           False     HARD      15.0  Ferrari       4.0
# 63033    SAI       47.0           False     HARD      16.0  Ferrari       4.0
# 63034    SAI       48.0           False     HARD      17.0  Ferrari       4.0
# 63035    SAI       49.0           False     HARD      18.0  Ferrari       4.0
# 63036    SAI       50.0           False     HARD      19.0  Ferrari       4.0
# 63037    SAI       51.0           False     HARD      20.0  Ferrari       4.0
# 63038    SAI       52.0           False     HARD      21.0  Ferrari       4.0
# 63039    SAI       53.0           False     HARD      22.0  Ferrari       4.0
# 63040    SAI       54.0           False     HARD      23.0  Ferrari       4.0
# 63041    SAI       55.0           False     HARD      24.0  Ferrari       4.0
# 63042    SAI       56.0           False     HARD      25.0  Ferrari       4.0
# 63043    SAI       57.0           False     HARD      26.0  Ferrari       4.0
#
#       Location  Year  LastTeamRanking  ...  status  RaceProgress  \
# 62992   Sakhir  2023              2.0  ...       1      0.105263
# 62993   Sakhir  2023              2.0  ...       1      0.122807
# 62994   Sakhir  2023              2.0  ...       1      0.140351
# 62995   Sakhir  2023              2.0  ...       1      0.157895
# 62996   Sakhir  2023              2.0  ...       1      0.175439
# 62997   Sakhir  2023              2.0  ...       1      0.192982
# 62998   Sakhir  2023              2.0  ...       1      0.210526
# 62999   Sakhir  2023              2.0  ...       1      0.228070
# 63000   Sakhir  2023              2.0  ...       1      0.245614
# 63001   Sakhir  2023              2.0  ...       1      0.263158
# 63002   Sakhir  2023              2.0  ...       1      0.280702
# 63003   Sakhir  2023              2.0  ...       1      0.298246
# 63004   Sakhir  2023              2.0  ...       1      0.315789
# 63005   Sakhir  2023              2.0  ...       1      0.333333
# 63006   Sakhir  2023              2.0  ...       1      0.350877
# 63007   Sakhir  2023              2.0  ...       1      0.368421
# 63008   Sakhir  2023              2.0  ...       1      0.385965
# 63009   Sakhir  2023              2.0  ...       1      0.403509
# 63010   Sakhir  2023              2.0  ...       1      0.421053
# 63011   Sakhir  2023              2.0  ...       1      0.438596
# 63012   Sakhir  2023              2.0  ...       1      0.456140
# 63013   Sakhir  2023              2.0  ...       1      0.473684
# 63014   Sakhir  2023              2.0  ...       1      0.491228
# 63015   Sakhir  2023              2.0  ...       1      0.508772
# 63016   Sakhir  2023              2.0  ...       1      0.526316
# 63017   Sakhir  2023              2.0  ...       1      0.543860
# 63018   Sakhir  2023              2.0  ...       1      0.561404
# 63019   Sakhir  2023              2.0  ...       1      0.578947
# 63020   Sakhir  2023              2.0  ...       1      0.596491
# 63021   Sakhir  2023              2.0  ...       1      0.614035
# 63022   Sakhir  2023              2.0  ...       1      0.631579
# 63023   Sakhir  2023              2.0  ...       1      0.649123
# 63024   Sakhir  2023              2.0  ...       1      0.666667
# 63025   Sakhir  2023              2.0  ...       1      0.684211
# 63026   Sakhir  2023              2.0  ...       1      0.701754
# 63027   Sakhir  2023              2.0  ...       7      0.719298
# 63028   Sakhir  2023              2.0  ...       1      0.736842
# 63029   Sakhir  2023              2.0  ...       1      0.754386
# 63030   Sakhir  2023              2.0  ...       1      0.771930
# 63031   Sakhir  2023              2.0  ...       1      0.789474
# 63032   Sakhir  2023              2.0  ...       1      0.807018
# 63033   Sakhir  2023              2.0  ...       1      0.824561
# 63034   Sakhir  2023              2.0  ...       1      0.842105
# 63035   Sakhir  2023              2.0  ...       1      0.859649
# 63036   Sakhir  2023              2.0  ...       1      0.877193
# 63037   Sakhir  2023              2.0  ...       1      0.894737
# 63038   Sakhir  2023              2.0  ...       1      0.912281
# 63039   Sakhir  2023              2.0  ...       1      0.929825
# 63040   Sakhir  2023              2.0  ...       1      0.947368
# 63041   Sakhir  2023              2.0  ...       1      0.964912
# 63042   Sakhir  2023              2.0  ...       1      0.982456
# 63043   Sakhir  2023              2.0  ...       1      1.000000
#
#        TyreStressLevel  TrackTemp  close_ahead  close_behind  \
# 62992                3       30.9         True          True
# 62993                3       30.9         True          True
# 62994                3       30.9         True          True
# 62995                3       30.8         True          True
# 62996                3       30.6         True          True
# 62997                3       30.6         True          True
# 62998                3       30.5         True          True
# 62999                3       30.5        False          True
# 63000                3       30.5        False         False
# 63001                3       30.5         True          True
# 63002                3       30.3        False          True
# 63003                3       30.3        False          True
# 63004                3       30.3         True          True
# 63005                3       30.2         True          True
# 63006                3       30.1         True          True
# 63007                3       30.1         True          True
# 63008                3       30.0         True          True
# 63009                3       29.9         True          True
# 63010                3       29.9         True          True
# 63011                3       29.9         True          True
# 63012                3       29.9        False          True
# 63013                3       29.9        False          True
# 63014                3       29.9        False          True
# 63015                3       29.7        False          True
# 63016                3       29.7        False          True
# 63017                3       29.6        False          True
# 63018                3       29.6         True          True
# 63019                3       29.6         True          True
# 63020                3       29.6        False          True
# 63021                3       29.6        False          True
# 63022                3       29.6        False          True
# 63023                3       29.5        False          True
# 63024                3       29.5        False          True
# 63025                3       29.5        False          True
# 63026                3       29.4         True          True
# 63027                3       29.4         True          True
# 63028                3       29.3         True         False
# 63029                3       29.2         True         False
# 63030                3       29.1         True         False
# 63031                3       29.1        False         False
# 63032                3       29.0         True         False
# 63033                3       29.0         True         False
# 63034                3       29.0         True         False
# 63035                3       29.0         True         False
# 63036                3       29.0         True         False
# 63037                3       28.9         True          True
# 63038                3       28.8         True          True
# 63039                3       28.8         True          True
# 63040                3       28.8         True          True
# 63041                3       28.7         True          True
# 63042                3       28.7         True          True
# 63043                3       28.7         True          True
#
#        is_pitting_ahead  is_pitting_behind  RealPitting  ModelPitting
# 62992             False              False            0             0
# 62993             False              False            0             0
# 62994             False              False            0             0
# 62995             False              False            0             1
# 62996             False              False            0             1
# 62997             False              False            0             1
# 62998             False              False            1             1
# 62999             False              False            0             1
# 63000             False              False            0             0
# 63001              True              False            0             0
# 63002             False              False            0             0
# 63003             False              False            0             0
# 63004             False              False            0             0
# 63005             False              False            0             0
# 63006             False              False            0             0
# 63007             False              False            0             0
# 63008             False              False            0             0
# 63009             False              False            0             0
# 63010             False              False            0             0
# 63011             False              False            0             0
# 63012             False              False            0             0
# 63013             False              False            0             0
# 63014             False              False            0             0
# 63015             False              False            0             0
# 63016             False              False            1             0
# 63017             False              False            0             0
# 63018             False              False            0             0
# 63019             False              False            0             0
# 63020             False              False            0             0
# 63021             False              False            0             0
# 63022             False              False            0             0
# 63023             False              False            0             0
# 63024             False              False            0             0
# 63025             False              False            0             0
# 63026             False              False            0             0
# 63027             False              False            0             0
# 63028             False              False            0             0
# 63029             False              False            0             0
# 63030             False              False            0             0
# 63031             False              False            0             0
# 63032             False              False            0             0
# 63033             False              False            0             0
# 63034             False              False            0             0
# 63035             False              False            0             0
# 63036             False              False            0             0
# 63037             False              False            0             0
# 63038             False              False            0             0
# 63039             False              False            0             0
# 63040             False              False            0             0
# 63041             False              False            0             0
# 63042             False              False            0             0
# 63043             False              False            0             0
#
# [52 rows x 21 columns]

# %% [markdown]
# LECLERC
# Barcelona: Nul, aucun pit
# Baku: très bon (bonne pred mais 1 tour de retard)
# Jeddah:bon sur le vrai pit mais donne 2 tours plus haut
# Melbourne:
# Sakhir:
#
#
# SAINZ
# Barcelona: Bonne fenêtre
# Baku: très bon (bonne pred mais 1 tour de retard)
# Jeddah: predis 1 en dessous 1 au dessus mais pas le bon
# Melbourne: Très mauvais, pas de pit
# Sakhir: sur 2 pit, le 1er il predit la bonne fenetre mais 5 fois de suite. Ne predit pas le 2eme

# %% [markdown]
# # SVM

# %% [markdown]
# # Random Forest
